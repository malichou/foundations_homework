# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

requests.get('https://darksky.net/dev')
# Out:
# <Response [200]>

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
# I was born in Athens, Greece.
# The latitude there would be 37.9838 and the longtitude 23.7275°.

requests.get('https://api.darksky.net/forecast/35df63408928cb994aa3acf11eef8e7b/37.9838,23.7275')

response = requests.get('https://api.darksky.net/forecast/35df63408928cb994aa3acf11eef8e7b/37.9838,23.7275')
response.json()
# Out:
# {'latitude': 37.9838,
#  'longitude': 23.7275,
#  'timezone': 'Europe/Athens',
#  'currently': {'time': 1560205455,
#   'summary': 'Clear',
#   'icon': 'clear-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 75.92,
#   'apparentTemperature': 75.92,
#   'dewPoint': 56.82,
#   'humidity': 0.52,
#   'pressure': 1011.15,
#   'windSpeed': 6.18,
#   'windGust': 12.33,
#   'windBearing': 331,
#   'cloudCover': 0,
#   'uvIndex': 0,
#   'visibility': 6.58,
#   'ozone': 330.01},
#  'hourly': {'summary': 'Partly cloudy starting tomorrow evening, continuing until tomorrow night.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1560204000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 76.26,
#     'apparentTemperature': 76.26,
#     'dewPoint': 56.84,
#     'humidity': 0.51,
#     'pressure': 1011.28,
#     'windSpeed': 6.17,
#     'windGust': 12.48,
# ...

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
# 'windSpeed': 6.18,
# 'windGust': 12.33,
# 'windBearing': 331,

# %%
print("Current windspeed is 6.18")
# Out:
# Current windspeed is 6.18

# %%
windspeed = 6.18
windgust = 12.33

difference = windgust - windspeed

print("The difference between how it feels and how it actually is would be", difference, "degrees.")
# Out:
# The difference between how it feels and how it actually is would be 6.15 degrees.

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %%
# I think the way to find the first forecast is by using 'hourly', as it brings the result just after midnight.
# So:

requests.get('https://api.darksky.net/forecast/35df63408928cb994aa3acf11eef8e7b/37.9838,23.7275?hourly')

response = requests.get('https://api.darksky.net/forecast/35df63408928cb994aa3acf11eef8e7b/37.9838,23.7275?hourly')
response.json()

# Guess it's one of these: 'cloudCover': 0, 'uvIndex': 0,
# Out:
# {'latitude': 37.9838,
#  'longitude': 23.7275,
#  'timezone': 'Europe/Athens',
#  'currently': {'time': 1560222283,
#   'summary': 'Clear',
#   'icon': 'clear-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 73.43,
#   'apparentTemperature': 73.43,
#   'dewPoint': 57.61,
#   'humidity': 0.58,
#   'pressure': 1010.4,
#   'windSpeed': 5.31,
#   'windGust': 11.75,
#   'windBearing': 331,
#   'cloudCover': 0,
#   'uvIndex': 0,
#   'visibility': 6.29,
#   'ozone': 331.54},
#  'hourly': {'summary': 'Partly cloudy this evening.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1560222000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 73.31,
#     'apparentTemperature': 73.31,
#     'dewPoint': 57.58,
#     'humidity': 0.58,
#     'pressure': 1010.39,
#     'windSpeed': 5.31,
#     'windGust': 11.74,
#     'windBearing': 331,
#     'cloudCover': 0,
# ...

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %%
requests.get('https://api.darksky.net/forecast/35df63408928cb994aa3acf11eef8e7b/37.9838,23.7275?temperatureMax')

response = requests.get('https://api.darksky.net/forecast/35df63408928cb994aa3acf11eef8e7b/37.9838,23.7275?temperatureMax')
response.json()

# %%
requests.get('https://api.darksky.net/forecast/35df63408928cb994aa3acf11eef8e7b/37.9838,23.7275?temperatureMin')

response = requests.get('https://api.darksky.net/forecast/35df63408928cb994aa3acf11eef8e7b/37.9838,23.7275?temperatureMin')
response.json()
# Out:
# {'latitude': 37.9838,
#  'longitude': 23.7275,
#  'timezone': 'Europe/Athens',
#  'currently': {'time': 1560222789,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 73.63,
#   'apparentTemperature': 73.63,
#   'dewPoint': 57.68,
#   'humidity': 0.57,
#   'pressure': 1010.43,
#   'windSpeed': 5.32,
#   'windGust': 11.75,
#   'windBearing': 332,
#   'cloudCover': 0,
#   'uvIndex': 0,
#   'visibility': 6.42,
#   'ozone': 331.52},
#  'hourly': {'summary': 'Partly cloudy this evening.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1560222000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 73.31,
#     'apparentTemperature': 73.31,
#     'dewPoint': 57.58,
#     'humidity': 0.58,
#     'pressure': 1010.39,
#     'windSpeed': 5.31,
#     'windGust': 11.74,
#     'windBearing': 331,
#     'cloudCover': 0,
# ...

# %%
top_temperature = 73.59
low_temperature = 57.68


difference = top_temperature - low_temperature

print('The difference between the top and the lowest temperature today is', round(difference), 'degrees')
# Out:
# The difference between the top and the lowest temperature today is 16 degrees

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %%
# Here i have to do the if > 85 print stuff

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# # - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# # - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*

# %%
# UNIX time would be: 1356393600
# And latitude and longtitude of NY would be: 40.7128° N, 74.0060° W



requests.get('https://api.darksky.net/forecast/35df63408928cb994aa3acf11eef8e7b/40.1728,74.0060?1356393600')

response = requests.get('https://api.darksky.net/forecast/35df63408928cb994aa3acf11eef8e7b/40.1728,74.0060?1356393600')
response.json()
# Out:
# {'latitude': 40.1728,
#  'longitude': 74.006,
#  'timezone': 'Asia/Bishkek',
#  'currently': {'time': 1560220885,
#   'summary': 'Flurries',
#   'icon': 'snow',
#   'precipIntensity': 0.0067,
#   'precipProbability': 0.2,
#   'precipType': 'snow',
#   'temperature': 23.51,
#   'apparentTemperature': 23.51,
#   'dewPoint': 23.51,
#   'humidity': 1,
#   'pressure': 1017.05,
#   'windSpeed': 1.6,
#   'windGust': 1.79,
#   'windBearing': 328,
#   'cloudCover': 0.99,
#   'uvIndex': 2,
#   'visibility': 1.54,
#   'ozone': 333.55},
#  'hourly': {'summary': 'Light snow (< 1 in.) later this morning and this afternoon.',
#   'icon': 'snow',
#   'data': [{'time': 1560218400,
#     'summary': 'Possible Light Snow',
#     'icon': 'snow',
#     'precipIntensity': 0.0081,
#     'precipProbability': 0.21,
#     'precipAccumulation': 0.111,
#     'precipType': 'snow',
#     'temperature': 22.52,
#     'apparentTemperature': 22.52,
#     'dewPoint': 22.52,
#     'humidity': 1,
# ...

# %%
# UNIX time for 2007 would be: 1198540800

requests.get('https://api.darksky.net/forecast/35df63408928cb994aa3acf11eef8e7b/40.1728,74.0060?1198540800')

response = requests.get('https://api.darksky.net/forecast/35df63408928cb994aa3acf11eef8e7b/40.1728,74.0060?1198540800')
response.json()
# Out:
# {'latitude': 40.1728,
#  'longitude': 74.006,
#  'timezone': 'Asia/Bishkek',
#  'currently': {'time': 1560221000,
#   'summary': 'Flurries',
#   'icon': 'snow',
#   'precipIntensity': 0.0067,
#   'precipProbability': 0.2,
#   'precipType': 'snow',
#   'temperature': 23.56,
#   'apparentTemperature': 23.56,
#   'dewPoint': 23.56,
#   'humidity': 1,
#   'pressure': 1017.03,
#   'windSpeed': 1.62,
#   'windGust': 1.8,
#   'windBearing': 327,
#   'cloudCover': 0.99,
#   'uvIndex': 2,
#   'visibility': 1.54,
#   'ozone': 333.62},
#  'hourly': {'summary': 'Light snow (< 1 in.) later this morning and this afternoon.',
#   'icon': 'snow',
#   'data': [{'time': 1560218400,
#     'summary': 'Possible Light Snow',
#     'icon': 'snow',
#     'precipIntensity': 0.0081,
#     'precipProbability': 0.21,
#     'precipAccumulation': 0.111,
#     'precipType': 'snow',
#     'temperature': 22.52,
#     'apparentTemperature': 22.52,
#     'dewPoint': 22.52,
#     'humidity': 1,
# ...

# %%
# UNIX time for 2005 would be: 1135468800

requests.get('https://api.darksky.net/forecast/35df63408928cb994aa3acf11eef8e7b/40.1728,74.0060?1135468800')

response = requests.get('https://api.darksky.net/forecast/35df63408928cb994aa3acf11eef8e7b/40.1728,74.0060?1135468800')
response.json()
# Out:
# {'latitude': 40.1728,
#  'longitude': 74.006,
#  'timezone': 'Asia/Bishkek',
#  'currently': {'time': 1560221618,
#   'summary': 'Flurries',
#   'icon': 'snow',
#   'precipIntensity': 0.0063,
#   'precipProbability': 0.2,
#   'precipType': 'snow',
#   'temperature': 23.81,
#   'apparentTemperature': 23.81,
#   'dewPoint': 23.81,
#   'humidity': 1,
#   'pressure': 1016.95,
#   'windSpeed': 1.75,
#   'windGust': 1.85,
#   'windBearing': 319,
#   'cloudCover': 1,
#   'uvIndex': 2,
#   'visibility': 1.55,
#   'ozone': 334.03},
#  'hourly': {'summary': 'Light snow (< 1 in.) later this morning and this afternoon.',
#   'icon': 'snow',
#   'data': [{'time': 1560218400,
#     'summary': 'Possible Light Snow',
#     'icon': 'snow',
#     'precipIntensity': 0.0081,
#     'precipProbability': 0.21,
#     'precipAccumulation': 0.111,
#     'precipType': 'snow',
#     'temperature': 22.52,
#     'apparentTemperature': 22.52,
#     'dewPoint': 22.52,
#     'humidity': 1,
#     'pressure': 1017.4,
# ...

# %%
# It allows you to go up to the midnight of 01/01/1970
